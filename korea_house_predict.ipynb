# %%
import pandas as pd

# %%
a=pd.read_csv('house1.csv',encoding='euc-kr')
b=pd.read_csv('house2.csv',encoding='euc-kr')
c=pd.read_csv('house3.csv',encoding='euc-kr')
d=pd.read_csv('house4.csv',encoding='euc-kr')
e=pd.read_csv('house5.csv',encoding='euc-kr')
f=pd.read_csv('house6.csv',encoding='euc-kr')

# %%
df=pd.concat([a,b,c,d,e,f])

# %%
df_train=df.loc[:,['법정동코드','법정동명','지번','특수지구분명','토지대장면적','산정대지면적','건물전체연면적','건물산정연면적','표준지여부','주택가격']]

# %%
df_train.head(10)
# Out:
#         법정동코드              법정동명     지번 특수지구분명  토지대장면적  산정대지면적  건물전체연면적  \
# 0  4874025031  경상남도 창녕군 창녕읍 탐하리    154     일반   942.0   302.0    36.37
# 1  4874025031  경상남도 창녕군 창녕읍 탐하리    154     일반   942.0   337.0    26.42
# 2  4874025031  경상남도 창녕군 창녕읍 탐하리  156-6     일반   413.0   413.0    79.13
# 3  4874025031  경상남도 창녕군 창녕읍 탐하리  156-7     일반   394.0   394.0    76.18
# 4  4874025031  경상남도 창녕군 창녕읍 탐하리    159     일반   212.0   212.0    70.87
# 5  4874025031  경상남도 창녕군 창녕읍 탐하리    160     일반   725.0   725.0   119.45
# 6  4874025031  경상남도 창녕군 창녕읍 탐하리    161     일반   208.0   208.0    78.88
# 7  4874025031  경상남도 창녕군 창녕읍 탐하리    164     일반   238.0   238.0    67.86
# 8  4874025031  경상남도 창녕군 창녕읍 탐하리    165     일반   645.0   645.0    72.60
# 9  4874025031  경상남도 창녕군 창녕읍 탐하리  187-2     일반   810.0   810.0    39.57
#
#    건물산정연면적 표준지여부      주택가격
# 0    36.37     N   7770000
# 1    26.42     N   7850000
# 2    79.13     N  41300000
# 3    76.18     N  45600000
# 4    70.87     N   7020000
# ...

# %%
df_train.shape
# Out:
# (156275, 10)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 156275 entries, 0 to 30325
# Data columns (total 10 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   법정동코드    156275 non-null  int64
#  1   법정동명     156275 non-null  object
#  2   지번       156275 non-null  object
#  3   특수지구분명   156275 non-null  object
#  4   토지대장면적   156275 non-null  float64
#  5   산정대지면적   156275 non-null  float64
#  6   건물전체연면적  156275 non-null  float64
#  7   건물산정연면적  156275 non-null  float64
#  8   표준지여부    156275 non-null  object
#  9   주택가격     156275 non-null  int64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 13.1+ MB

# %%
df_train.columns=['legal-code','legal-name','dist-num','is_special','land_area','counting_area','total_area','building_area','is_standard','price']

# %%
df_train.head()
# Out:
#    legal-code        legal-name dist-num is_special  land_area  counting_area  \
# 0  4874025031  경상남도 창녕군 창녕읍 탐하리      154         일반      942.0          302.0
# 1  4874025031  경상남도 창녕군 창녕읍 탐하리      154         일반      942.0          337.0
# 2  4874025031  경상남도 창녕군 창녕읍 탐하리    156-6         일반      413.0          413.0
# 3  4874025031  경상남도 창녕군 창녕읍 탐하리    156-7         일반      394.0          394.0
# 4  4874025031  경상남도 창녕군 창녕읍 탐하리      159         일반      212.0          212.0
#
#    total_area  building_area is_standard     price
# 0       36.37          36.37           N   7770000
# 1       26.42          26.42           N   7850000
# 2       79.13          79.13           N  41300000
# 3       76.18          76.18           N  45600000
# 4       70.87          70.87           N   7020000

# %%
(df_train['price']==0).value_counts()
# Out:
# False    155017
# True       1258
# Name: price, dtype: int64

# %%
df_train=df_train.loc[df_train['price']!=0]
print(df_train.shape)
# Out:
# (155017, 10)

# %%
df_train['dist_num1']=df_train['dist-num'].str.split('-').str.get(0)
df_train['dist_num2']=df_train['dist-num'].str.split('-').str.get(1)

# %%
df_train.head()
# Out:
#    legal-code        legal-name dist-num is_special  land_area  counting_area  \
# 0  4874025031  경상남도 창녕군 창녕읍 탐하리      154         일반      942.0          302.0
# 1  4874025031  경상남도 창녕군 창녕읍 탐하리      154         일반      942.0          337.0
# 2  4874025031  경상남도 창녕군 창녕읍 탐하리    156-6         일반      413.0          413.0
# 3  4874025031  경상남도 창녕군 창녕읍 탐하리    156-7         일반      394.0          394.0
# 4  4874025031  경상남도 창녕군 창녕읍 탐하리      159         일반      212.0          212.0
#
#    total_area  building_area is_standard     price dist_num1 dist_num2
# 0       36.37          36.37           N   7770000       154       NaN
# 1       26.42          26.42           N   7850000       154       NaN
# 2       79.13          79.13           N  41300000       156         6
# 3       76.18          76.18           N  45600000       156         7
# 4       70.87          70.87           N   7020000       159       NaN

# %%
df_train.drop('dist-num',axis=1,inplace=True)

# %%
df_train.head()
# Out:
#    legal-code        legal-name is_special  land_area  counting_area  \
# 0  4874025031  경상남도 창녕군 창녕읍 탐하리         일반      942.0          302.0
# 1  4874025031  경상남도 창녕군 창녕읍 탐하리         일반      942.0          337.0
# 2  4874025031  경상남도 창녕군 창녕읍 탐하리         일반      413.0          413.0
# 3  4874025031  경상남도 창녕군 창녕읍 탐하리         일반      394.0          394.0
# 4  4874025031  경상남도 창녕군 창녕읍 탐하리         일반      212.0          212.0
#
#    total_area  building_area is_standard     price dist_num1 dist_num2
# 0       36.37          36.37           N   7770000       154       NaN
# 1       26.42          26.42           N   7850000       154       NaN
# 2       79.13          79.13           N  41300000       156         6
# 3       76.18          76.18           N  45600000       156         7
# 4       70.87          70.87           N   7020000       159       NaN

# %%
df_train['dist_num1'].isna().value_counts()
# Out:
# False    109708
# True      45309
# Name: dist_num1, dtype: int64

# %%
df_train['dist_num1']=df_train['dist_num1'].fillna('0')
df_train['dist_num2']=df_train['dist_num2'].fillna('0')

# %%
df_train['dist_num1'].isna().value_counts()
# Out:
# False    155017
# Name: dist_num1, dtype: int64

# %%
df_train['dist_num2'].isna().value_counts()
# Out:
# False    155017
# Name: dist_num2, dtype: int64

# %%
df_train.head()
# Out:
#    legal-code        legal-name is_special  land_area  counting_area  \
# 0  4874025031  경상남도 창녕군 창녕읍 탐하리         일반      942.0          302.0
# 1  4874025031  경상남도 창녕군 창녕읍 탐하리         일반      942.0          337.0
# 2  4874025031  경상남도 창녕군 창녕읍 탐하리         일반      413.0          413.0
# 3  4874025031  경상남도 창녕군 창녕읍 탐하리         일반      394.0          394.0
# 4  4874025031  경상남도 창녕군 창녕읍 탐하리         일반      212.0          212.0
#
#    total_area  building_area is_standard     price dist_num1 dist_num2
# 0       36.37          36.37           N   7770000       154         0
# 1       26.42          26.42           N   7850000       154         0
# 2       79.13          79.13           N  41300000       156         6
# 3       76.18          76.18           N  45600000       156         7
# 4       70.87          70.87           N   7020000       159         0

# %%
df_train['dist_num1']=df_train['dist_num1'].astype(int)
df_train['dist_num2']=df_train['dist_num2'].astype(int)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc=LabelEncoder()
df_train['is_special']=enc.fit_transform(df_train['is_special'])

# %%
df_train.head()
# Out:
#    legal-code        legal-name  is_special  land_area  counting_area  \
# 0  4874025031  경상남도 창녕군 창녕읍 탐하리           2      942.0          302.0
# 1  4874025031  경상남도 창녕군 창녕읍 탐하리           2      942.0          337.0
# 2  4874025031  경상남도 창녕군 창녕읍 탐하리           2      413.0          413.0
# 3  4874025031  경상남도 창녕군 창녕읍 탐하리           2      394.0          394.0
# 4  4874025031  경상남도 창녕군 창녕읍 탐하리           2      212.0          212.0
#
#    total_area  building_area is_standard     price  dist_num1  dist_num2
# 0       36.37          36.37           N   7770000        154          0
# 1       26.42          26.42           N   7850000        154          0
# 2       79.13          79.13           N  41300000        156          6
# 3       76.18          76.18           N  45600000        156          7
# 4       70.87          70.87           N   7020000        159          0

# %%
df_train['is_special'].value_counts()
# Out:
# 2    154130
# 1       886
# 0         1
# Name: is_special, dtype: int64

# %%
df_train['legal_name0']=df_train['legal-name'].str.split(' ').str.get(0)
df_train['legal_name1']=df_train['legal-name'].str.split(' ').str.get(1)
df_train['legal_name2']=df_train['legal-name'].str.split(' ').str.get(2)
df_train['legal_name3']=df_train['legal-name'].str.split(' ').str.get(3)

df_train=df_train.drop('legal-name',axis=1)

# %%
df_train.head()
# Out:
#    legal-code  is_special  land_area  counting_area  total_area  \
# 0  4874025031           2      942.0          302.0       36.37
# 1  4874025031           2      942.0          337.0       26.42
# 2  4874025031           2      413.0          413.0       79.13
# 3  4874025031           2      394.0          394.0       76.18
# 4  4874025031           2      212.0          212.0       70.87
#
#    building_area is_standard     price  dist_num1  dist_num2 legal_name0  \
# 0          36.37           N   7770000        154          0        경상남도
# 1          26.42           N   7850000        154          0        경상남도
# 2          79.13           N  41300000        156          6        경상남도
# 3          76.18           N  45600000        156          7        경상남도
# 4          70.87           N   7020000        159          0        경상남도
#
#   legal_name1 legal_name2 legal_name3
# 0         창녕군         창녕읍         탐하리
# 1         창녕군         창녕읍         탐하리
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df_train['legal_name3'].isna().value_counts()
# Out:
# False    120479
# True      34538
# Name: legal_name3, dtype: int64

# %%
df_train['legal_name3']=df_train['legal_name3'].fillna('')

# %%
df_train['legal_name3'].isna().value_counts()
# Out:
# False    155017
# Name: legal_name3, dtype: int64

# %%
df_train['is_standard'].value_counts()
# Out:
# N    150906
# Y      4111
# Name: is_standard, dtype: int64

# %%
enc=LabelEncoder()

# %%
df_train['is_standard']=enc.fit_transform(df_train['is_standard'])
df_train['legal_name0']=enc.fit_transform(df_train['legal_name0'])
df_train['legal_name1']=enc.fit_transform(df_train['legal_name1'])
df_train['legal_name2']=enc.fit_transform(df_train['legal_name2'])
df_train['legal_name3']=enc.fit_transform(df_train['legal_name3'])

# %%
def see(a):
    df_train.head(a)
    return df_train.head(a)

# %%
see(10)
# Out:
#    legal-code  is_special  land_area  counting_area  total_area  \
# 0  4874025031           2      942.0          302.0       36.37
# 1  4874025031           2      942.0          337.0       26.42
# 2  4874025031           2      413.0          413.0       79.13
# 3  4874025031           2      394.0          394.0       76.18
# 4  4874025031           2      212.0          212.0       70.87
# 5  4874025031           2      725.0          725.0      119.45
# 6  4874025031           2      208.0          208.0       78.88
# 7  4874025031           2      238.0          238.0       67.86
# 8  4874025031           2      645.0          645.0       72.60
# 9  4874025031           2      810.0          810.0       39.57
#
#    building_area  is_standard     price  dist_num1  dist_num2  legal_name0  \
# 0          36.37            0   7770000        154          0            0
# 1          26.42            0   7850000        154          0            0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

sns.set()
sns.pairplot(df_train[['building_area','price']],height=3)
plt.show()

# %%
df_train['price']=df_train['price']/100000000

# %%
see(5)
# Out:
#    legal-code  is_special  land_area  counting_area  total_area  \
# 0  4874025031           2      942.0          302.0       36.37
# 1  4874025031           2      942.0          337.0       26.42
# 2  4874025031           2      413.0          413.0       79.13
# 3  4874025031           2      394.0          394.0       76.18
# 4  4874025031           2      212.0          212.0       70.87
#
#    building_area  is_standard   price  dist_num1  dist_num2  legal_name0  \
# 0          36.37            0  0.0777        154          0            0
# 1          26.42            0  0.0785        154          0            0
# 2          79.13            0  0.4130        156          6            0
# 3          76.18            0  0.4560        156          7            0
# 4          70.87            0  0.0702        159          0            0
#
#    legal_name1  legal_name2  legal_name3
# 0            4          101          384
# 1            4          101          384
# ...

# %%
df_inlier=df_train[df_train['building_area']<6000]

# %%
from scipy.stats import probplot
sns.distplot(df_train['price'],)
fig=plt.figure(figsize=(8,6))
probplot(df_train['price'],plot=plt)
# Out:
# ((array([-4.4412728 , -4.24656538, -4.14080422, ...,  4.14080422,
#           4.24656538,  4.4412728 ]),
#   array([3.66e-03, 3.77e-03, 4.04e-03, ..., 3.72e+01, 3.96e+01, 3.97e+01])),
#  (0.907820361979392, 0.8820924247663159, 0.790783561083763))

# %%
import numpy as np

sns.distplot(np.log1p(df_train['price']))
fig=plt.figure(figsize=(8,6))
probplot(df_train['price'],plot=plt)
# Out:
# ((array([-4.4412728 , -4.24656538, -4.14080422, ...,  4.14080422,
#           4.24656538,  4.4412728 ]),
#   array([3.66e-03, 3.77e-03, 4.04e-03, ..., 3.72e+01, 3.96e+01, 3.97e+01])),
#  (0.907820361979392, 0.8820924247663159, 0.790783561083763))

# %%
from sklearn.model_selection import train_test_split

df_train['price']=np.log1p(df_train['price'])

# %%
see(5)
# Out:
#    legal-code  is_special  land_area  counting_area  total_area  \
# 0  4874025031           2      942.0          302.0       36.37
# 1  4874025031           2      942.0          337.0       26.42
# 2  4874025031           2      413.0          413.0       79.13
# 3  4874025031           2      394.0          394.0       76.18
# 4  4874025031           2      212.0          212.0       70.87
#
#    building_area  is_standard     price  dist_num1  dist_num2  legal_name0  \
# 0          36.37            0  0.074829        154          0            0
# 1          26.42            0  0.075571        154          0            0
# 2          79.13            0  0.345715        156          6            0
# 3          76.18            0  0.375693        156          7            0
# 4          70.87            0  0.067846        159          0            0
#
#    legal_name1  legal_name2  legal_name3
# 0            4          101          384
# 1            4          101          384
# ...

# %%
feature=df_train[df_train.drop('price',axis=1).columns.values]
target=df_train['price']

# %%
X_train,X_test,y_train,y_test=train_test_split(feature,target,test_size=0.33,random_state=2019)

# %%
from keras.layers import Input, Dense
from keras.models import Model
from keras import regularizers

# %%
def create_model():
    inputs=Input(shape=(13,))
    
    fc1=Dense(64,activation='tanh',kernel_initializer='glorot_normal',kernel_regularizer=regularizers.l1(0.01))(inputs)
    dr1=Dropout(0.5)(fc1)
    fc2=Dense(128,activation='tanh',kernel_initializer='glorot_normal',kernel_regularizer=regularizers.l1(0.01))(dr1)
    dr1=Dropout(0.3)(fc1)
    outputs=Dense(1,activation='sigmoid')(fc2)
    
    model=Model(inputs=inputs,outputs=outputs)
    return model

# %%
from keras import metrics
model=create_model()
model.summary()
model.compile(optimizer='sgd',loss='mean_squared_error',metrics=[metrics.mae])
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 13)]              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                896
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# ...
# Total params: 9,345
# Trainable params: 9,345
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(X_train,y_train, validation_data=(X_test,y_test),epochs=5,batch_size=128)
# Out:
# Epoch 1/5
# 812/812 [==============================] - 5s 4ms/step - loss: 6.6191 - mean_absolute_error: 0.3181 - val_loss: 2.8366 - val_mean_absolute_error: 0.3092
# Epoch 2/5
# 812/812 [==============================] - 3s 3ms/step - loss: 2.1203 - mean_absolute_error: 0.3052 - val_loss: 0.6833 - val_mean_absolute_error: 0.3020
# Epoch 3/5
# 812/812 [==============================] - 3s 4ms/step - loss: 0.4993 - mean_absolute_error: 0.3035 - val_loss: 0.2400 - val_mean_absolute_error: 0.3049
# Epoch 4/5
# 812/812 [==============================] - 4s 5ms/step - loss: 0.2210 - mean_absolute_error: 0.3050 - val_loss: 0.1819 - val_mean_absolute_error: 0.3062
# Epoch 5/5
# 812/812 [==============================] - 3s 3ms/step - loss: 0.1795 - mean_absolute_error: 0.3054 - val_loss: 0.1765 - val_mean_absolute_error: 0.3057
